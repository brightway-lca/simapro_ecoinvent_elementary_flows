# %% [markdown]
# # Match - Identical names in water
#
# If the name is exactly the same, then we can be pretty confidant there is a 1-1 correspondence. We need to do different base contexts separately, as there can be small implementation differences or other gotchas in each one.

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime, timezone

# %% [markdown]
# Get paths of input and output directories

# %%
input_data_dir = (Path.cwd().parent / "Mapping" / "Input" / "Flowlists").resolve()
existing_matches_dir = (Path.cwd().parent / "Mapping" / "Output" / "Mapped_files").resolve()
output_dir = (Path.cwd().parent / "Contribute").resolve()

# %% [markdown]
# Read input dataframes

# %%
sp = pd.read_csv(input_data_dir / 'SimaProv9.4.csv')

# %%
ei = pd.read_csv(input_data_dir / 'ecoinventEFv3.7.csv')

# %%
sp.Context.unique()
# Out:
# array(['Raw materials', 'Airborne emissions', 'Waterborne emissions',
#        'Final waste flows', 'Emissions to soil', 'Non material emissions',
#        'Social issues', 'Economic issues'], dtype=object)

# %%
sorted(ei.Context.unique())
# Out:
# ['air/indoor',
#  'air/low population density, long-term',
#  'air/lower stratosphere + upper troposphere',
#  'air/non-urban air or from high stacks',
#  'air/unspecified',
#  'air/urban air close to ground',
#  'natural resource/biotic',
#  'natural resource/fossil well',
#  'natural resource/in air',
#  'natural resource/in ground',
#  'natural resource/in water',
#  'natural resource/land',
#  'soil/agricultural',
#  'soil/forestry',
#  'soil/industrial',
#  'soil/unspecified',
#  'water/fossil well',
#  'water/ground-',
#  'water/ground-, long-term',
#  'water/ocean',
#  'water/surface water',
#  'water/unspecified']

# %% [markdown]
# # Dealing with different `Context` values and available levels
#
# The names might match, but we also need the `Context` to match. To do this we need to match the `Context` systems from `simapro` and `ecoinvent`. We can normalize to either system, but as we are matching to ecoinvent, we also match to ecoinvent `Context` values.
#
# In this notebook we look only at emissions to water, so restrict ourselves to these contexts:

# %%
sp = sp[sp.Context == 'Waterborne emissions']
ei = ei[ei.Context.str.startswith("water/")]

# %% [markdown]
# The Simapro flows only have one `Context`, but we need all the subcontexts available in ecoinvent. They are also available in Simapro, but not given in our master flow list. Therefore, we can use an [outer](https://www.ionos.com/digitalguide/hosting/technical-matters/sql-outer-join/) [merge](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html) to expand the Simapro contexts to match one Simapro flow against all relevant ecoinvent flows:

# %%
sp[sp.Flowable == '1-Pentanol']
# Out:
#         Flowable       CAS No Formula    Synonyms Unit                 Class  \
# 5734  1-Pentanol  000071-41-0     NaN  1-Pentanol   kg  Waterborne emissions
#
#                    Context                             Flow UUID  \
# 5734  Waterborne emissions  CBD72D82-FB5E-49B5-821E-A808A79E0A2B
#
#            Description
# 5734  Formula: C5H12O

# %%
ei[ei.Flowable == '1-Pentanol']
# Out:
#       Flowable        CASNo Formula      Synonyms Unit     Class  \
# 16  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
# 17  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
# 18  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
# 19  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
# 20  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
#
#     ExternalReference  Preferred                   Context  \
# 16                NaN        NaN             water/ground-
# 17                NaN        NaN  water/ground-, long-term
# 18                NaN        NaN               water/ocean
# 19                NaN        NaN       water/surface water
# 20                NaN        NaN         water/unspecified
#
#                                 FlowUUID  AltUnit  Unnamed: 11  \
# 16  5074e239-b510-49aa-928c-fcdb462481d8      NaN          NaN
# 17  cfa50eaf-a817-4352-b9fe-aa834240d269      NaN          NaN
# 18  8d28a5b3-1b1c-41e9-9eba-90c607aad7db      NaN          NaN
# 19  e4526360-b2a1-4e77-9f00-57dbfe228bde      NaN          NaN
# 20  070dc6b3-0976-45a0-803e-0a87d7e96959      NaN          NaN
#
#                                            Second CAS
# 16  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 17  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 18  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 19  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 20  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...

# %% [markdown]
# ## Merging the two `Contexts`

# %%
WATER_CONTEXT_CORRESPONDENCE = pd.DataFrame([
    # ecoinvent context, simapro context, match condition ei to sp, match condition sp to ei
    ('water/fossil well', 'Emissions to water/groundwater, long-term', "~", "~"),
    ('water/ground-', 'Emissions to water/groundwater', "=", "="),
    ('water/ground-, long-term', 'Emissions to water/groundwater, long-term', "=", "="),
    ('water/ocean', 'Emissions to water/ocean', "=", "="),
    ('water/surface water', 'Emissions to water/lake', ">", "<"),
    ('water/surface water', 'Emissions to water/river', ">", "<"),
    ('water/surface water', 'Emissions to water/river, long-term', ">", "<"),
    ('water/unspecified', 'Emissions to water/(unspecified)', "=", "="),
], columns=["EI_Context", "SP_Context", "MatchCondition_EI_to_SP", "MatchCondition_SP_to_EI"])

# %% [markdown]
# We can just expand each Simapro flow by the number of possible complete `Context` values using a cross product:

# %%
sp_expanded = sp.merge(WATER_CONTEXT_CORRESPONDENCE, how="cross")

# %% [markdown]
# Fix the column `SP_Context` to be the normal `Context`:

# %%
sp_expanded.drop(columns=["Context"], inplace=True)
sp_expanded.rename(columns={"SP_Context": "Context"}, inplace=True)

# %%
sp_expanded[sp_expanded.Flowable == '1-Pentanol']
# Out:
#        Flowable       CAS No Formula    Synonyms Unit                 Class  \
# 544  1-Pentanol  000071-41-0     NaN  1-Pentanol   kg  Waterborne emissions
# 545  1-Pentanol  000071-41-0     NaN  1-Pentanol   kg  Waterborne emissions
# 546  1-Pentanol  000071-41-0     NaN  1-Pentanol   kg  Waterborne emissions
# 547  1-Pentanol  000071-41-0     NaN  1-Pentanol   kg  Waterborne emissions
# 548  1-Pentanol  000071-41-0     NaN  1-Pentanol   kg  Waterborne emissions
# 549  1-Pentanol  000071-41-0     NaN  1-Pentanol   kg  Waterborne emissions
# 550  1-Pentanol  000071-41-0     NaN  1-Pentanol   kg  Waterborne emissions
# 551  1-Pentanol  000071-41-0     NaN  1-Pentanol   kg  Waterborne emissions
#
#                                 Flow UUID       Description  \
# 544  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 545  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 546  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 547  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 548  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 549  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 550  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 551  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
#
#                    EI_Context                                    Context  \
# 544         water/fossil well  Emissions to water/groundwater, long-term
# 545             water/ground-             Emissions to water/groundwater
# 546  water/ground-, long-term  Emissions to water/groundwater, long-term
# 547               water/ocean                   Emissions to water/ocean
# 548       water/surface water                    Emissions to water/lake
# 549       water/surface water                   Emissions to water/river
# 550       water/surface water        Emissions to water/river, long-term
# 551         water/unspecified           Emissions to water/(unspecified)
#
#     MatchCondition_EI_to_SP MatchCondition_SP_to_EI
# 544                       ~                       ~
# 545                       =                       =
# 546                       =                       =
# 547                       =                       =
# 548                       >                       <
# 549                       >                       <
# 550                       >                       <
# 551                       =                       =

# %% [markdown]
# # Merging based on identical names and `Context`
#
# Once we have the `Context` systems aligned, it is quite simple to merge the two dataframes and take results when the `Flowable` and `Context` match exactly.

# %%
df = sp_expanded.merge(ei, how="inner", left_on=["Flowable", "EI_Context"], right_on=["Flowable", "Context"])

# %%
df[df.Flowable == '1-Pentanol']
# Out:
#      Flowable       CAS No Formula_x  Synonyms_x Unit_x               Class_x  \
# 0  1-Pentanol  000071-41-0       NaN  1-Pentanol     kg  Waterborne emissions
# 1  1-Pentanol  000071-41-0       NaN  1-Pentanol     kg  Waterborne emissions
# 2  1-Pentanol  000071-41-0       NaN  1-Pentanol     kg  Waterborne emissions
# 3  1-Pentanol  000071-41-0       NaN  1-Pentanol     kg  Waterborne emissions
# 4  1-Pentanol  000071-41-0       NaN  1-Pentanol     kg  Waterborne emissions
# 5  1-Pentanol  000071-41-0       NaN  1-Pentanol     kg  Waterborne emissions
# 6  1-Pentanol  000071-41-0       NaN  1-Pentanol     kg  Waterborne emissions
#
#                               Flow UUID       Description  \
# 0  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 1  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 2  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 3  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 4  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 5  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
# 6  CBD72D82-FB5E-49B5-821E-A808A79E0A2B  Formula: C5H12O
#
#                  EI_Context                                  Context_x  ...  \
# 0             water/ground-             Emissions to water/groundwater  ...
# 1  water/ground-, long-term  Emissions to water/groundwater, long-term  ...
# 2               water/ocean                   Emissions to water/ocean  ...
# 3       water/surface water                    Emissions to water/lake  ...
# 4       water/surface water                   Emissions to water/river  ...
# 5       water/surface water        Emissions to water/river, long-term  ...
# 6         water/unspecified           Emissions to water/(unspecified)  ...
#
#      Synonyms_y Unit_y   Class_y ExternalReference Preferred  \
# 0  amyl alcohol     kg  chemical               NaN       NaN
# 1  amyl alcohol     kg  chemical               NaN       NaN
# 2  amyl alcohol     kg  chemical               NaN       NaN
# 3  amyl alcohol     kg  chemical               NaN       NaN
# 4  amyl alcohol     kg  chemical               NaN       NaN
# 5  amyl alcohol     kg  chemical               NaN       NaN
# 6  amyl alcohol     kg  chemical               NaN       NaN
#
#                   Context_y                              FlowUUID  AltUnit  \
# 0             water/ground-  5074e239-b510-49aa-928c-fcdb462481d8      NaN
# 1  water/ground-, long-term  cfa50eaf-a817-4352-b9fe-aa834240d269      NaN
# 2               water/ocean  8d28a5b3-1b1c-41e9-9eba-90c607aad7db      NaN
# 3       water/surface water  e4526360-b2a1-4e77-9f00-57dbfe228bde      NaN
# 4       water/surface water  e4526360-b2a1-4e77-9f00-57dbfe228bde      NaN
# 5       water/surface water  e4526360-b2a1-4e77-9f00-57dbfe228bde      NaN
# 6         water/unspecified  070dc6b3-0976-45a0-803e-0a87d7e96959      NaN
#
#    Unnamed: 11                                         Second CAS
# 0          NaN  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 1          NaN  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 2          NaN  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 3          NaN  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 4          NaN  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 5          NaN  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 6          NaN  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
#
# [7 rows x 24 columns]

# %% [markdown]
# # Fixing different units
#
# There are only a few cases where this is an issue, and only one conversion factor to add:

# %%
df[df.Unit_x != df.Unit_y]
# Out:
#      Flowable       CAS No Formula_x Synonyms_x Unit_x               Class_x  \
# 1745    Water  007732-18-5       NaN      Water     kg  Waterborne emissions
# 1746    Water  007732-18-5       NaN      Water     kg  Waterborne emissions
# 1747    Water  007732-18-5       NaN      Water     kg  Waterborne emissions
# 1748    Water  007732-18-5       NaN      Water     kg  Waterborne emissions
# 1749    Water  007732-18-5       NaN      Water     kg  Waterborne emissions
# 1750    Water  007732-18-5       NaN      Water     kg  Waterborne emissions
# 1751    Water  007732-18-5       NaN      Water     kg  Waterborne emissions
# 1752    Water  007732-18-5       NaN      Water     kg  Waterborne emissions
#
#                                  Flow UUID Description  \
# 1745  E0F21491-61BA-44CF-B0A1-0A3670B63F8D         NaN
# 1746  E0F21491-61BA-44CF-B0A1-0A3670B63F8D         NaN
# 1747  E0F21491-61BA-44CF-B0A1-0A3670B63F8D         NaN
# 1748  E0F21491-61BA-44CF-B0A1-0A3670B63F8D         NaN
# 1749  E0F21491-61BA-44CF-B0A1-0A3670B63F8D         NaN
# 1750  E0F21491-61BA-44CF-B0A1-0A3670B63F8D         NaN
# 1751  E0F21491-61BA-44CF-B0A1-0A3670B63F8D         NaN
# 1752  E0F21491-61BA-44CF-B0A1-0A3670B63F8D         NaN
#
#                     EI_Context                                  Context_x  \
# 1745         water/fossil well  Emissions to water/groundwater, long-term
# 1746             water/ground-             Emissions to water/groundwater
# 1747  water/ground-, long-term  Emissions to water/groundwater, long-term
# 1748               water/ocean                   Emissions to water/ocean
# 1749       water/surface water                    Emissions to water/lake
# 1750       water/surface water                   Emissions to water/river
# 1751       water/surface water        Emissions to water/river, long-term
# 1752         water/unspecified           Emissions to water/(unspecified)
#
#       ... Synonyms_y Unit_y Class_y ExternalReference Preferred  \
# 1745  ...        NaN     m3   water               NaN       NaN
# 1746  ...        NaN     m3   water               NaN       NaN
# 1747  ...        NaN     m3   water               NaN       NaN
# 1748  ...        NaN     m3   water               NaN       NaN
# 1749  ...        NaN     m3   water               NaN       NaN
# 1750  ...        NaN     m3   water               NaN       NaN
# 1751  ...        NaN     m3   water               NaN       NaN
# 1752  ...        NaN     m3   water               NaN       NaN
#
#                      Context_y                              FlowUUID  AltUnit  \
# 1745         water/fossil well  2256a142-8242-4b4f-b9aa-a167803989ca      NaN
# 1746             water/ground-  51254820-3456-4373-b7b4-056cf7b16e01      NaN
# 1747  water/ground-, long-term  06d4812b-6937-4d64-8517-b69aabce3648      NaN
# 1748               water/ocean  4f0f15b3-b227-4cdc-b0b3-6412d55695d5      NaN
# 1749       water/surface water  db4566b1-bd88-427d-92da-2d25879063b9      NaN
# 1750       water/surface water  db4566b1-bd88-427d-92da-2d25879063b9      NaN
# 1751       water/surface water  db4566b1-bd88-427d-92da-2d25879063b9      NaN
# 1752         water/unspecified  2404b41a-2eed-4e9d-8ab6-783946fdf5d6      NaN
#
#       Unnamed: 11             Second CAS
# 1745          NaN  13670-17-2; 7732-18-5
# 1746          NaN  13670-17-2; 7732-18-5
# 1747          NaN  13670-17-2; 7732-18-5
# 1748          NaN  13670-17-2; 7732-18-5
# 1749          NaN  13670-17-2; 7732-18-5
# 1750          NaN  13670-17-2; 7732-18-5
# 1751          NaN  13670-17-2; 7732-18-5
# 1752          NaN  13670-17-2; 7732-18-5
#
# [8 rows x 24 columns]

# %%
df['ConversionFactor'] = pd.Series([1] * len(df))

# %%
water_mask = (df.Flowable == "Water") * (df.Unit_x == "kg") * (df.Unit_y == "m3")
water_mask.sum()
# Out:
# 8

# %%
df.loc[water_mask, 'ConversionFactor'] = 1e-3

# %% [markdown]
# # Finalize export

# %% [markdown]
# Adjust columns to match expected format:

# %%
def fix_names_after_merge(df):
    mapping = {
        'Flow UUID': 'SourceFlowUUID', 
        'FlowUUID': 'TargetFlowUUID',  # Incorrect column header in provided ecoinvent data
        'Flowable_x': 'SourceFlowName', 
        'Flowable_y': 'TargetFlowName',
        'Unit_x': 'SourceUnit',
        'Unit_y': 'TargetUnit',
        'Context_x': 'SourceFlowContext',
        'Context_y': 'TargetFlowContext',
    }
    return df.rename(columns={k: v for k, v in mapping.items() if k in df.columns})

# %%
df = fix_names_after_merge(df)

# %% [markdown]
# Add some useful columns.
#
# * `author` is your name
# * `notebook_name` is the name of this notebook; we can't figure this out automatically. It should normally start with `Match -`.
# * `default_match_condition` is one of `=`, `~`, `<`, or `>`.

# %%
def add_common_columns(df, author, notebook_name, default_match_condition="="):
    df['SourceListName'] = 'SimaPro9.4'
    df['TargetListName'] = 'ecoinventEFv3.7'
    df['MatchCondition'] = default_match_condition
    df['Mapper'] = author
    df['MemoMapper'] = f'Automated match. Notebook: {notebook_name}'
    df['MemoSource'] = ''
    df['MemoTarget'] = ''
    df['MemoVerifier'] = ''
    df['LastUpdated'] = datetime.now(timezone.utc).astimezone().isoformat()
    df['Verifier'] = ''
    return df

# %%
df = add_common_columns(df, "Chris Mutel", "Match - Identical names in water")

# %% [markdown]
# Make sure the required columns are present

# %%
def check_required_columns(df):
    expected = set([     
        "SourceListName", "SourceFlowName", "SourceFlowUUID", "SourceFlowContext", "SourceUnit", 
        "MatchCondition", "TargetListName", "TargetFlowName", "TargetFlowUUID", 
        "TargetFlowContext", "TargetUnit", "Mapper", "Verifier", "LastUpdated", "MemoMapper", 
        "MemoVerifier", "MemoSource", "MemoTarget"
    ])
    given = set(df.columns)
    difference = expected.difference(given)
    if difference:
        print("Missing the following required columns:", difference)

# %%
check_required_columns(df)
# Out:
# Missing the following required columns: {'TargetFlowName', 'SourceFlowName'}

# %% [markdown]
# The names are exactly the same, so we can just duplicate them:

# %%
df['SourceFlowName'] = df['TargetFlowName'] = df['Flowable']

# %%
check_required_columns(df)

# %% [markdown]
# Export the dataframe to the `contribute` directory. Please make your filename meaningful.

# %%
def export_dataframe(df, name):
    SPEC_COLUMNS = [
        "SourceListName", "SourceFlowName", "SourceFlowUUID", "SourceFlowContext", "SourceUnit", 
        "MatchCondition", "ConversionFactor", "TargetListName", "TargetFlowName", "TargetFlowUUID", 
        "TargetFlowContext", "TargetUnit", "Mapper", "Verifier", "LastUpdated", "MemoMapper", 
        "MemoVerifier", "MemoSource", "MemoTarget"
    ]
    
    df = df[[col for col in SPEC_COLUMNS if col in df.columns]]
    
    if not name.lower().endswith(".csv"):
        name += ".csv"
    
    df.to_csv(output_dir / name, index=False)

# %%
export_dataframe(df, 'identical-names-in-water')
