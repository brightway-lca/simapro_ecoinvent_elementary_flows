# %% [markdown]
# # Match - Identical names in air
#
# If the name is exactly the same, then we can be pretty confidant there is a 1-1 correspondence. We need to do different base contexts separately, as there can be small implementation differences or other gotchas in each one.

# %%
import pandas as pd
from pathlib import Path
from datetime import datetime, timezone

# %% [markdown]
# Get paths of input and output directories

# %%
input_data_dir = (Path.cwd().parent / "Mapping" / "Input" / "Flowlists").resolve()
existing_matches_dir = (Path.cwd().parent / "Mapping" / "Output" / "Mapped_files").resolve()
output_dir = (Path.cwd().parent / "Contribute").resolve()

# %% [markdown]
# Read input dataframes

# %%
sp = pd.read_csv(input_data_dir / 'SimaProv9.4.csv')

# %%
ei = pd.read_csv(input_data_dir / 'ecoinventEFv3.7.csv')

# %% [markdown]
# # Dealing with different `Context` values and available levels
#
# The names might match, but we also need the `Context` to match. To do this we need to match the `Context` systems from `simapro` and `ecoinvent`. We can normalize to either system, but as we are matching to ecoinvent, we also match to ecoinvent `Context` values.
#
# In this notebook we look only at emissions to air, so restrict ourselves to these contexts:

# %%
sp = sp[sp.Context == 'Airborne emissions']
ei = ei[ei.Context.str.startswith("air/")]

# %% [markdown]
# The Simapro flows only have one `Context`, but we need all the subcontexts available in ecoinvent. They are also available in Simapro, but not given in our master flow list. Therefore, we can use an [outer](https://www.ionos.com/digitalguide/hosting/technical-matters/sql-outer-join/) [merge](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html) to expand the Simapro contexts to match one Simapro flow against all relevant ecoinvent flows:

# %%
sp[sp.Flowable == '1-Pentanol']
# Out:
#        Flowable       CAS No       Formula    Synonyms Unit  \
# 858  1-Pentanol  000071-41-0  C10H12N2O5   1-Pentanol   kg
#
#                   Class             Context  \
# 858  Airborne emissions  Airborne emissions
#
#                                 Flow UUID Description
# 858  5E6F7EF4-1C2C-414A-BB7D-D29AE6450363         NaN

# %%
ei[ei.Flowable == '1-Pentanol']
# Out:
#       Flowable        CASNo Formula      Synonyms Unit     Class  \
# 11  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
# 12  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
# 13  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
# 14  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
# 15  1-Pentanol  000071-41-0     NaN  amyl alcohol   kg  chemical
#
#     ExternalReference  Preferred                                     Context  \
# 11                NaN        NaN       air/low population density, long-term
# 12                NaN        NaN  air/lower stratosphere + upper troposphere
# 13                NaN        NaN       air/non-urban air or from high stacks
# 14                NaN        NaN                             air/unspecified
# 15                NaN        NaN               air/urban air close to ground
#
#                                 FlowUUID  AltUnit  Unnamed: 11  \
# 11  9dd01d5b-3677-4822-9cd4-36d21b0e23d1      NaN          NaN
# 12  b78e77cb-7636-4420-855e-17239984f8b3      NaN          NaN
# 13  cc9a442f-c96a-4bdc-990d-8b58f72b4e07      NaN          NaN
# 14  048baf1e-6cdc-44a5-92e2-32d15ff54885      NaN          NaN
# 15  541a823c-0aad-4dc4-9123-d4af4647d942      NaN          NaN
#
#                                            Second CAS
# 11  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 12  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 13  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 14  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 15  158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...

# %% [markdown]
# ## Merging the two `Contexts`

# %%
air_categories = pd.DataFrame([
    ('Airborne emissions', 'air/indoor',),
    ('Airborne emissions', 'air/low population density, long-term',),
    ('Airborne emissions', 'air/lower stratosphere + upper troposphere',),
    ('Airborne emissions', 'air/non-urban air or from high stacks',),
    ('Airborne emissions', 'air/unspecified',),
    ('Airborne emissions', 'air/urban air close to ground'),
], columns=["Context", "EI_Context"])

# %%
sp_expanded = sp.merge(air_categories, how="outer", on="Context")
sp_expanded[sp_expanded.Flowable == '1-Pentanol']
# Out:
#        Flowable       CAS No       Formula    Synonyms Unit  \
# 864  1-Pentanol  000071-41-0  C10H12N2O5   1-Pentanol   kg
# 865  1-Pentanol  000071-41-0  C10H12N2O5   1-Pentanol   kg
# 866  1-Pentanol  000071-41-0  C10H12N2O5   1-Pentanol   kg
# 867  1-Pentanol  000071-41-0  C10H12N2O5   1-Pentanol   kg
# 868  1-Pentanol  000071-41-0  C10H12N2O5   1-Pentanol   kg
# 869  1-Pentanol  000071-41-0  C10H12N2O5   1-Pentanol   kg
#
#                   Class             Context  \
# 864  Airborne emissions  Airborne emissions
# 865  Airborne emissions  Airborne emissions
# 866  Airborne emissions  Airborne emissions
# 867  Airborne emissions  Airborne emissions
# 868  Airborne emissions  Airborne emissions
# 869  Airborne emissions  Airborne emissions
#
#                                 Flow UUID Description  \
# 864  5E6F7EF4-1C2C-414A-BB7D-D29AE6450363         NaN
# 865  5E6F7EF4-1C2C-414A-BB7D-D29AE6450363         NaN
# 866  5E6F7EF4-1C2C-414A-BB7D-D29AE6450363         NaN
# 867  5E6F7EF4-1C2C-414A-BB7D-D29AE6450363         NaN
# 868  5E6F7EF4-1C2C-414A-BB7D-D29AE6450363         NaN
# 869  5E6F7EF4-1C2C-414A-BB7D-D29AE6450363         NaN
#
#                                      EI_Context
# 864                                  air/indoor
# 865       air/low population density, long-term
# 866  air/lower stratosphere + upper troposphere
# 867       air/non-urban air or from high stacks
# 868                             air/unspecified
# 869               air/urban air close to ground

# %% [markdown]
# ## Fixing the Simapro `Context`
#
# In the master flow list, we only have base `Context` values, like `"Airborne emissions"`. However, in Simapro CSV exports we know that we will get more specific contexts, as we can match these one-to-one with the ecoinvent `Context` values.
#
# **Note**: This won't be perfect. In the latest data we have available, the SimaPro CSVs use slightly different values depending on the kind of CSV data being exported. For examples, you might find:
#
# * In the master flow list: `Airborne emissions`
# * In an LCI file: `Emissions to air`
# * In an LCIA file: `Air`
#
# There is no *right* answer, but we will use the LCI variant, as that is the most common import type. We can correct these later in the import step if necessary.

# %%
ei_to_sp_context = {
    'air/indoor': 'Emissions to air/indoor',
    'air/low population density, long-term': 'Emissions to air/low. pop., long-term',
    'air/lower stratosphere + upper troposphere': 'Emissions to air/stratosphere + troposphere',
    'air/non-urban air or from high stacks': 'Emissions to air/low. pop.',
    'air/unspecified': 'Emissions to air/(unspecified)',
    'air/urban air close to ground': 'Emissions to air/high. pop.',
}
mapped_context = sp_expanded.EI_Context.replace(ei_to_sp_context)
sp_expanded.Context = mapped_context

# %% [markdown]
# # Merging based on identical names and `Context`
#
# Once we have the `Context` systems aligned, it is quite simple to merge the two dataframes and take results when the `Flowable` and `Context` match exactly.

# %%
df = sp_expanded.merge(ei, how="inner", left_on=["Flowable", "EI_Context"], right_on=["Flowable", "Context"])

# %%
df
# Out:
#           Flowable       CAS No     Formula_x    Synonyms_x Unit_x  \
# 0       1-Pentanol  000071-41-0  C10H12N2O5     1-Pentanol     kg
# 1       1-Pentanol  000071-41-0  C10H12N2O5     1-Pentanol     kg
# 2       1-Pentanol  000071-41-0  C10H12N2O5     1-Pentanol     kg
# 3       1-Pentanol  000071-41-0  C10H12N2O5     1-Pentanol     kg
# 4       1-Pentanol  000071-41-0  C10H12N2O5     1-Pentanol     kg
# ...            ...          ...           ...           ...    ...
# 1561  Zirconium-95  013967-71-0           NaN  Zirconium-95    kBq
# 1562  Zirconium-95  013967-71-0           NaN  Zirconium-95    kBq
# 1563  Zirconium-95  013967-71-0           NaN  Zirconium-95    kBq
# 1564  Zirconium-95  013967-71-0           NaN  Zirconium-95    kBq
# 1565  Zirconium-95  013967-71-0           NaN  Zirconium-95    kBq
#
#                  Class_x                                    Context_x  \
# 0     Airborne emissions        Emissions to air/low. pop., long-term
# 1     Airborne emissions  Emissions to air/stratosphere + troposphere
# 2     Airborne emissions                   Emissions to air/low. pop.
# 3     Airborne emissions               Emissions to air/(unspecified)
# 4     Airborne emissions                  Emissions to air/high. pop.
# ...                  ...                                          ...
# 1561  Airborne emissions        Emissions to air/low. pop., long-term
# 1562  Airborne emissions  Emissions to air/stratosphere + troposphere
# 1563  Airborne emissions                   Emissions to air/low. pop.
# 1564  Airborne emissions               Emissions to air/(unspecified)
# 1565  Airborne emissions                  Emissions to air/high. pop.
#
#                                  Flow UUID      Description  \
# 0     5E6F7EF4-1C2C-414A-BB7D-D29AE6450363              NaN
# 1     5E6F7EF4-1C2C-414A-BB7D-D29AE6450363              NaN
# 2     5E6F7EF4-1C2C-414A-BB7D-D29AE6450363              NaN
# 3     5E6F7EF4-1C2C-414A-BB7D-D29AE6450363              NaN
# 4     5E6F7EF4-1C2C-414A-BB7D-D29AE6450363              NaN
# ...                                    ...              ...
# 1561  97A3FD41-4B43-4BFB-9054-12F3CDA6B78B  Formula: Zr-95
# 1562  97A3FD41-4B43-4BFB-9054-12F3CDA6B78B  Formula: Zr-95
# 1563  97A3FD41-4B43-4BFB-9054-12F3CDA6B78B  Formula: Zr-95
# 1564  97A3FD41-4B43-4BFB-9054-12F3CDA6B78B  Formula: Zr-95
# 1565  97A3FD41-4B43-4BFB-9054-12F3CDA6B78B  Formula: Zr-95
#
#                                       EI_Context  ...    Synonyms_y Unit_y  \
# 0          air/low population density, long-term  ...  amyl alcohol     kg
# 1     air/lower stratosphere + upper troposphere  ...  amyl alcohol     kg
# 2          air/non-urban air or from high stacks  ...  amyl alcohol     kg
# 3                                air/unspecified  ...  amyl alcohol     kg
# 4                  air/urban air close to ground  ...  amyl alcohol     kg
# ...                                          ...  ...           ...    ...
# 1561       air/low population density, long-term  ...           NaN    kBq
# 1562  air/lower stratosphere + upper troposphere  ...           NaN    kBq
# 1563       air/non-urban air or from high stacks  ...           NaN    kBq
# 1564                             air/unspecified  ...           NaN    kBq
# 1565               air/urban air close to ground  ...           NaN    kBq
#
#        Class_y ExternalReference Preferred  \
# 0     chemical               NaN       NaN
# 1     chemical               NaN       NaN
# 2     chemical               NaN       NaN
# 3     chemical               NaN       NaN
# 4     chemical               NaN       NaN
# ...        ...               ...       ...
# 1561  chemical               NaN       NaN
# 1562  chemical               NaN       NaN
# 1563  chemical               NaN       NaN
# 1564  chemical               NaN       NaN
# 1565  chemical               NaN       NaN
#
#                                        Context_y  \
# 0          air/low population density, long-term
# 1     air/lower stratosphere + upper troposphere
# 2          air/non-urban air or from high stacks
# 3                                air/unspecified
# 4                  air/urban air close to ground
# ...                                          ...
# 1561       air/low population density, long-term
# 1562  air/lower stratosphere + upper troposphere
# 1563       air/non-urban air or from high stacks
# 1564                             air/unspecified
# 1565               air/urban air close to ground
#
#                                   FlowUUID AltUnit Unnamed: 11  \
# 0     9dd01d5b-3677-4822-9cd4-36d21b0e23d1     NaN         NaN
# 1     b78e77cb-7636-4420-855e-17239984f8b3     NaN         NaN
# 2     cc9a442f-c96a-4bdc-990d-8b58f72b4e07     NaN         NaN
# 3     048baf1e-6cdc-44a5-92e2-32d15ff54885     NaN         NaN
# 4     541a823c-0aad-4dc4-9123-d4af4647d942     NaN         NaN
# ...                                    ...     ...         ...
# 1561  7e59174a-d66b-4304-81dc-e0aeb3c58ae2     NaN         NaN
# 1562  ae941326-4981-44fa-8be1-8757aab10d00     NaN         NaN
# 1563  fa260f53-4850-4585-9b67-5cdbc603c5ef     NaN         NaN
# 1564  88a02d30-d9fe-4dc1-b1e5-e95745df0956     NaN         NaN
# 1565  498c8296-8f0c-4aa9-869b-78bb6c299c3a     NaN         NaN
#
#                                              Second CAS
# 0     158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 1     158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 2     158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 3     158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# 4     158778-85-9; 71-41-0; 64118-19-0; 30899-19-5; ...
# ...                                                 ...
# 1561                                         13967-71-0
# 1562                                         13967-71-0
# 1563                                         13967-71-0
# 1564                                         13967-71-0
# 1565                                         13967-71-0
#
# [1566 rows x 22 columns]

# %% [markdown]
# # Fixing different units
#
# There are only a few cases where this is an issue, and only one conversion factor to add:

# %%
df[df.Unit_x != df.Unit_y]
# Out:
#      Flowable       CAS No Formula_x Synonyms_x Unit_x             Class_x  \
# 1500    Water  007732-18-5       NaN      Water     kg  Airborne emissions
# 1501    Water  007732-18-5       NaN      Water     kg  Airborne emissions
# 1502    Water  007732-18-5       NaN      Water     kg  Airborne emissions
# 1503    Water  007732-18-5       NaN      Water     kg  Airborne emissions
# 1504    Water  007732-18-5       NaN      Water     kg  Airborne emissions
#
#                                         Context_x  \
# 1500        Emissions to air/low. pop., long-term
# 1501  Emissions to air/stratosphere + troposphere
# 1502                   Emissions to air/low. pop.
# 1503               Emissions to air/(unspecified)
# 1504                  Emissions to air/high. pop.
#
#                                  Flow UUID    Description  \
# 1500  C7E61CA8-9E6E-4743-B1F8-1CE425AFAE83  Formula: H2O
# 1501  C7E61CA8-9E6E-4743-B1F8-1CE425AFAE83  Formula: H2O
# 1502  C7E61CA8-9E6E-4743-B1F8-1CE425AFAE83  Formula: H2O
# 1503  C7E61CA8-9E6E-4743-B1F8-1CE425AFAE83  Formula: H2O
# 1504  C7E61CA8-9E6E-4743-B1F8-1CE425AFAE83  Formula: H2O
#
#                                       EI_Context  ... Synonyms_y Unit_y  \
# 1500       air/low population density, long-term  ...        NaN     m3
# 1501  air/lower stratosphere + upper troposphere  ...        NaN     m3
# 1502       air/non-urban air or from high stacks  ...        NaN     m3
# 1503                             air/unspecified  ...        NaN     m3
# 1504               air/urban air close to ground  ...        NaN     m3
#
#      Class_y ExternalReference Preferred  \
# 1500   water               NaN       NaN
# 1501   water               NaN       NaN
# 1502   water               NaN       NaN
# 1503   water               NaN       NaN
# 1504   water               NaN       NaN
#
#                                        Context_y  \
# 1500       air/low population density, long-term
# 1501  air/lower stratosphere + upper troposphere
# 1502       air/non-urban air or from high stacks
# 1503                             air/unspecified
# 1504               air/urban air close to ground
#
#                                   FlowUUID AltUnit Unnamed: 11  \
# 1500  f977a02e-3564-4798-843c-9fb9a18bc18b     NaN         NaN
# 1501  f14b59ff-d438-442d-8bad-b53694b8263a     NaN         NaN
# 1502  09872080-d143-4fb1-a3a5-647b077107ff     NaN         NaN
# 1503  075e433b-4be4-448e-9510-9a5029c1ce94     NaN         NaN
# 1504  5d368100-b1bc-4456-8420-e469edccf349     NaN         NaN
#
#                  Second CAS
# 1500  13670-17-2; 7732-18-5
# 1501  13670-17-2; 7732-18-5
# 1502  13670-17-2; 7732-18-5
# 1503  13670-17-2; 7732-18-5
# 1504  13670-17-2; 7732-18-5
#
# [5 rows x 22 columns]

# %%
df['ConversionFactor'] = pd.Series([1] * len(df))

# %%
water_mask = (df.Flowable == "Water") * (df.Unit_x == "kg") * (df.Unit_y == "m3")
water_mask.sum()
# Out:
# 5

# %%
df.loc[water_mask, 'ConversionFactor'] = 1e-3

# %% [markdown]
# # Finalize export

# %% [markdown]
# Adjust columns to match expected format:

# %%
def fix_names_after_merge(df):
    mapping = {
        'Flow UUID': 'SourceFlowUUID', 
        'FlowUUID': 'TargetFlowUUID',  # Incorrect column header in provided ecoinvent data
        'Flowable_x': 'SourceFlowName', 
        'Flowable_y': 'TargetFlowName',
        'Unit_x': 'SourceUnit',
        'Unit_y': 'TargetUnit',
        'Context_x': 'SourceFlowContext',
        'Context_y': 'TargetFlowContext',
    }
    return df.rename(columns={k: v for k, v in mapping.items() if k in df.columns})

# %%
df = fix_names_after_merge(df)

# %% [markdown]
# Add some useful columns.
#
# * `author` is your name
# * `notebook_name` is the name of this notebook; we can't figure this out automatically. It should normally start with `Match -`.
# * `default_match_condition` is one of `=`, `~`, `<`, or `>`.

# %%
def add_common_columns(df, author, notebook_name, default_match_condition="="):
    df['SourceListName'] = 'SimaPro9.4'
    df['TargetListName'] = 'ecoinventEFv3.7'
    df['MatchCondition'] = default_match_condition
    df['Mapper'] = author
    df['MemoMapper'] = f'Automated match. Notebook: {notebook_name}'
    df['MemoSource'] = ''
    df['MemoTarget'] = ''
    df['MemoVerifier'] = ''
    df['LastUpdated'] = datetime.now(timezone.utc).astimezone().isoformat()
    df['Verifier'] = ''
    return df

# %%
df = add_common_columns(df, "Chris Mutel", "Match - Identical names in air")

# %% [markdown]
# Make sure the required columns are present

# %%
def check_required_columns(df):
    expected = set([     
        "SourceListName", "SourceFlowName", "SourceFlowUUID", "SourceFlowContext", "SourceUnit", 
        "MatchCondition", "TargetListName", "TargetFlowName", "TargetFlowUUID", 
        "TargetFlowContext", "TargetUnit", "Mapper", "Verifier", "LastUpdated", "MemoMapper", 
        "MemoVerifier", "MemoSource", "MemoTarget"
    ])
    given = set(df.columns)
    difference = expected.difference(given)
    if difference:
        print("Missing the following required columns:", difference)

# %%
check_required_columns(df)
# Out:
# Missing the following required columns: {'TargetFlowName', 'SourceFlowName'}

# %% [markdown]
# The names are exactly the same, so we can just duplicate them:

# %%
df['SourceFlowName'] = df['TargetFlowName'] = df['Flowable']

# %% [markdown]
# Export the dataframe to the `contribute` directory. Please make your filename meaningful.

# %%
def export_dataframe(df, name):
    SPEC_COLUMNS = [
        "SourceListName", "SourceFlowName", "SourceFlowUUID", "SourceFlowContext", "SourceUnit", 
        "MatchCondition", "ConversionFactor", "TargetListName", "TargetFlowName", "TargetFlowUUID", 
        "TargetFlowContext", "TargetUnit", "Mapper", "Verifier", "LastUpdated", "MemoMapper", 
        "MemoVerifier", "MemoSource", "MemoTarget"
    ]
    
    df = df[[col for col in SPEC_COLUMNS if col in df.columns]]
    
    if not name.lower().endswith(".csv"):
        name += ".csv"
    
    df.to_csv(output_dir / name, index=False)

# %%
export_dataframe(df, 'identical-names-in-air')
