# %% [markdown]
# # Flow Mapping format
#
# Flow mapping data is in the form of a csv file with the unique source list acronymn, 'to' and the unique target list acronymn as the file name, e.g. 'IDEAv2.2toFEDEFLv1.0.3.csv'.
# See the [FlowMapping template](FlowMapping.csv).
#
# Field | Type | Required? | Note |
# ----- | ---- | --------  | ----------- |
# SourceListName | string | Y | Name and version of the source flowlist, e.g. `openLCA1.7` or `TRACI2.1` |
# SourceFlowName | string | Y | Name of the source flow |
# SourceFlowUUID | string | N | If no UUID present, UUID generated based on olca algorithm|
# SourceFlowContext | string | Y | Compartments separated by `/`, like `emission/air`|
# SourceUnit | string | Y | A unit abbreviation, like `kg`|
# MatchCondition | string | N |Single character. `=`, `>`,`<`,`~`. Meaning 'equal to','a superset of', 'a subset of', 'a proxy for'. Assumes `=` if not present |
# ConversionFactor | float | N | Value for multiplying with source flow to equal target flow. Assumes `1` if not   present |
# TargetListName | string | Y | Name and version of the target flowlist, e.g. openLCA1.7 or TRACI2.1
# TargetFlowName | string | Y | Name of the flowable |
# TargetFlowUUID | string| Y| UUID for target flow |
# TargetFlowContext | string | Y | Target context, in form like `emission/air` |
# TargetUnit | string | Y | A unit abbreviation, like `kg`|
# Mapper | string | N | Person creating the mapping |
# Verifier | string | N | Person verifying the mapping |
# LastUpdated | datetime | N | Date mapping last updated |
# MemoMapper | string | N	| Memo by Mapper
# MemoVerifier |	string | N | Memo by Verifier
# MemoSource | string	| N |	Memo by Source EF system admin
# MemoTarget | string	| N	| Memo by Target EF system admin

# %%
import pandas as pd

# %%
sp = pd.read_csv("input_data/SimaProv9.4.csv")
sp
# Out:
#                                                 Flowable       CAS No Formula  \
# 0                                               Actinium  007440-34-8     Ac
# 1                                                    Air  132259-10-0     NaN
# 2                                              Aluminium  007429-90-5     Al
# 3                                              Anhydrite  014798-04-0  CaSO4
# 4                                          Animal matter          NaN     NaN
# ...                                                  ...          ...     ...
# 13298  Compensation of employees incl. social contrib...          NaN     NaN
# 13299    Operating surplus: Consumption of fixed capital          NaN     NaN
# 13300  Operating surplus: Remaining net operating sur...          NaN     NaN
# 13301                      Other net taxes on production          NaN     NaN
# 13302  Taxes less subsidies on products purchased: Total          NaN     NaN
#
#                                                 Synonyms      Unit  \
# 0                                               Actinium        kg
# 1                                                    Air        kg
# 2                                              Aluminium        kg
# 3                                              Anhydrite        kg
# 4                                          Animal matter        kg
# ...                                                  ...       ...
# 13298  Compensation of employees incl. social contrib...  MEUR2011
# 13299    Operating surplus: Consumption of fixed capital  MEUR2011
# 13300  Operating surplus: Remaining net operating sur...  MEUR2011
# 13301                      Other net taxes on production  MEUR2011
# 13302  Taxes less subsidies on products purchased: Total  MEUR2011
#
#                  Class          Context                             Flow UUID  \
# 0        Raw materials    Raw materials  90004354-71D3-47E8-B322-300BA5A98F7B
# 1        Raw materials    Raw materials  09336180-36F4-4389-9F51-1548DF956B24
# 2        Raw materials    Raw materials  0CDDB90F-BD92-46DE-BBDF-B7244C502CEB
# 3        Raw materials    Raw materials  9F3A82FA-C5EC-4A67-A6BA-A8C70B506729
# 4        Raw materials    Raw materials  3AEDBE91-F73E-4283-ABDC-F5EFD119E784
# ...                ...              ...                                   ...
# 13298  Economic issues  Economic issues  1774FA7B-4603-420C-B5D7-A83EC47A5DE2
# 13299  Economic issues  Economic issues  59B51226-9703-4DD5-B060-833C46CA2CDC
# 13300  Economic issues  Economic issues  8B6D32E8-4257-44E0-A10E-9819CFB8A870
# 13301  Economic issues  Economic issues  9B212C13-1EEE-41ED-A6E9-19A10953787F
# 13302  Economic issues  Economic issues  A5A01CF9-38E5-4FCF-9513-096DE82245CE
#
#       Description
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 13298         NaN
# 13299         NaN
# 13300         NaN
# 13301         NaN
# 13302         NaN
#
# [13303 rows x 9 columns]

# %%
ei = pd.read_csv("input_data/ecoinventEFv3.7.csv")
ei
# Out:
#                 Flowable        CASNo Formula         Synonyms Unit     Class  \
# 0     1,3-Dioxolan-2-one  000096-49-1     NaN              NaN   kg  chemical
# 1         1,4-Butanediol  000110-63-4     NaN  Butylene glycol   kg  chemical
# 2         1,4-Butanediol  000110-63-4     NaN  Butylene glycol   kg  chemical
# 3         1,4-Butanediol  000110-63-4     NaN  Butylene glycol   kg  chemical
# 4         1,4-Butanediol  000110-63-4     NaN  Butylene glycol   kg  chemical
# ...                  ...          ...     ...              ...  ...       ...
# 4305        Zirconium-95  013967-71-0     NaN              NaN  kBq  chemical
# 4306        Zirconium-95  013967-71-0     NaN              NaN  kBq  chemical
# 4307        Zirconium-95  013967-71-0      Zr              NaN  kBq  chemical
# 4308        Zirconium-95  013967-71-0     NaN              NaN  kBq  chemical
# 4309            Zoxamide  156052-68-5     NaN              NaN   kg  chemical
#
#       ExternalReference  Preferred  \
# 0                   NaN        NaN
# 1                   NaN        NaN
# 2                   NaN        NaN
# 3                   NaN        NaN
# 4                   NaN        NaN
# ...                 ...        ...
# 4305                NaN        NaN
# 4306                NaN        NaN
# 4307                NaN        NaN
# 4308                NaN        NaN
# 4309                NaN        NaN
#
#                                          Context  \
# 0                              water/unspecified
# 1          air/low population density, long-term
# 2     air/lower stratosphere + upper troposphere
# 3          air/non-urban air or from high stacks
# 4                                air/unspecified
# ...                                          ...
# 4305                    water/ground-, long-term
# 4306                                 water/ocean
# 4307                         water/surface water
# 4308                           water/unspecified
# 4309                           soil/agricultural
#
#                                   FlowUUID  AltUnit  Unnamed: 11  \
# 0     5b7d620e-2238-5ec9-888a-6999218b6974      NaN          NaN
# 1     d21da01e-f96f-4db5-9746-7b70db8a1f2c      NaN          NaN
# 2     90653a29-2f53-4b1b-88bd-9ae2fe64a8d6      NaN          NaN
# 3     83bafcf1-2f2e-4a32-89a0-f1f16ca10626      NaN          NaN
# 4     09db39be-d9a6-4fc3-8d25-1f80b23e9131      NaN          NaN
# ...                                    ...      ...          ...
# 4305  ffd4940c-b652-4622-b7d0-d4d861b083c3      NaN          NaN
# 4306  aa7f8d81-9670-4a5c-af68-b50fbe247958      NaN          NaN
# 4307  8db2694c-9a3f-4f8d-a915-cd8a380f5394      NaN          NaN
# 4308  b71d0281-e4b2-4831-a2bd-aed221d2a15f      NaN          NaN
# 4309  03b40051-311b-5e37-aad1-ea811907cc90      NaN          NaN
#
#                                       Second CAS
# 0                                        96-49-1
# 1     36684-44-3; 28324-25-6; 110-63-4; 110-63-4
# 2     36684-44-3; 28324-25-6; 110-63-4; 110-63-4
# 3     36684-44-3; 28324-25-6; 110-63-4; 110-63-4
# 4     36684-44-3; 28324-25-6; 110-63-4; 110-63-4
# ...                                          ...
# 4305                                  13967-71-0
# 4306                                  13967-71-0
# 4307                                  13967-71-0
# 4308                                  13967-71-0
# 4309                                 156052-68-5
#
# [4310 rows x 13 columns]

# %% [markdown]
# Remove flows for which we know there is no correspondence

# %%
sp = sp[~sp.Context.isin(['Social issues', 'Economic issues', 'Final waste flows'])]

# %%
len(set(ei['Flowable']).intersection(set(sp['Synonyms'])))
# Out:
# 1023

# %%
len(set(ei['Flowable']).intersection(set(sp['Flowable'])))
# Out:
# 1021

# %%
sorted(set(ei['Flowable']).intersection(set(sp['Flowable'])))
# Out:
# ['1,3-Dioxolan-2-one',
#  '1,4-Butanediol',
#  '1-Pentanol',
#  '1-Pentene',
#  '2,4-D',
#  '2,4-D ester',
#  '2,4-di-tert-butylphenol',
#  '2-Amino-3-chloro-1,4-naphthoquinone',
#  '2-Aminopropanol',
#  '2-Methyl-1-propanol',
#  '2-Nitrobenzoic acid',
#  '2-Phenylphenol',
#  '2-Propanol',
#  '3-Methyl-1-butanol',
#  '4-Methyl-2-pentanol',
#  '4-Methyl-2-pentanone',
#  '8-Quinolinol',
#  'AOX, Adsorbable Organic Halogen as Cl',
#  'Abamectin',
#  'Acenaphthene',
#  'Acenaphthylene',
#  'Acephate',
#  'Acetaldehyde',
#  'Acetamide',
#  'Acetamiprid',
#  'Acetic acid',
#  'Acetic acid, trifluoro-',
#  'Acetochlor',
#  'Acetone',
#  'Acetonitrile',
#  'Acetyl chloride',
#  'Acidity, unspecified',
#  'Acifluorfen',
#  'Aclonifen',
#  'Acrinathrin',
#  'Acrolein',
#  'Acrylic acid',
#  'Acrylonitrile',
#  'Actinides, radioactive, unspecified',
#  'Aerosols, radioactive, unspecified',
#  'Alachlor',
#  'Alanycarb',
#  'Aldehydes, unspecified',
#  'Aldicarb',
#  'Aldrin',
#  'Allethrin',
#  'Allyl chloride',
#  'Alpha-cypermethrin',
#  'Aluminium',
#  'Aluminium hydroxide',
#  'Americium-241',
#  'Ametryn',
#  'Amidosulfuron',
#  'Amine oxide',
#  'Amitraz',
#  'Ammonia',
#  'Ammonium carbonate',
#  'Ammonium sulfate',
#  'Ammonium, ion',
#  'Anilazine',
#  'Aniline',
#  'Anthracene',
#  'Anthranilic acid',
#  'Anthraquinone',
#  'Antimony',
#  'Antimony-122',
#  'Antimony-124',
#  'Antimony-125',
#  'Argon-41',
#  'Arsenic',
#  'Arsenic, ion',
#  'Arsine',
#  'Asulam',
#  'Atrazine',
#  'Azaconazol',
#  'Azadirachtin',
#  'Azinphos-methyl',
#  'Aziprotryne',
#  'Azoxystrobin',
#  'Barite',
#  'Barium',
#  'Barium sulfide',
#  'Barium-140',
#  'Benalaxyl',
#  'Benazolin',
#  'Benfluralin',
#  'Benomyl',
#  'Benoxacor',
#  'Bensulfuron methyl ester',
#  'Bensultap',
#  'Bentazone',
#  'Benthiavalicarb',
#  'Benthiavalicarb-isopropyl',
#  'Benzal chloride',
#  'Benzaldehyde',
#  'Benzene',
#  'Benzene, chloro-',
#  'Benzene, ethyl-',
#  'Benzene, hexachloro-',
#  'Benzene, pentachloro-',
#  'Benzo(a)pyrene',
#  'Benzo(b)fluoranthene',
#  'Benzo(k)fluoranthene',
#  'Benzoic acid',
#  'Benzoximate',
#  'Benzthiazuron',
#  'Benzyl alcohol',
#  'Beryllium',
#  'Bicarbonate, ion',
#  'Bifenox',
#  'Bifenthrin',
#  'Bisphenol A',
#  'Bitertanol',
#  'Borate',
#  'Boric acid',
#  'Boron',
#  'Boron trifluoride',
#  'Boscalid',
#  'Bromacil',
#  'Bromate',
#  'Bromide',
#  'Bromine',
#  'Bromofenoxim',
#  'Bromopropane',
#  'Bromoxynil',
#  'Bromoxynil octanoate',
#  'Bromuconazole',
#  'Bupirimate',
#  'Buprofezin',
#  'Butadiene',
#  'Butafenacil',
#  'Butane',
#  'Butene',
#  'Butoxycarboxim',
#  'Butralin',
#  'Butyl acetate',
#  'Butylcarbamate, iodopropynyl',
#  'Butyrolactone',
#  'Cadmium',
#  'Cadmium-109',
#  'Calcium',
#  'Calcium cyanamide',
#  'Calcium hydroxide',
#  'Captan',
#  'Carbaryl',
#  'Carbendazim',
#  'Carbetamide',
#  'Carbofuran',
#  'Carbon',
#  'Carbon dioxide, fossil',
#  'Carbon dioxide, in air',
#  'Carbon dioxide, to soil or biomass stock',
#  'Carbon disulfide',
#  'Carbon monoxide, fossil',
#  'Carbon, organic, in soil or biomass stock',
#  'Carbon-14',
#  'Carbonate',
#  'Carbonyl sulfide',
#  'Carboxin',
#  'Carboxylic acids, unspecified',
#  'Carfentrazone-ethyl',
#  'Carnallite',
#  'Cerium-141',
#  'Cerium-144',
#  'Cesium',
#  'Cesium-134',
#  'Cesium-136',
#  'Cesium-137',
#  'Chloramine',
#  'Chlorate',
#  'Chlorbromuron',
#  'Chlorbufam',
#  'Chlorfenvinphos',
#  'Chloridazon',
#  'Chloride',
#  'Chlorides, unspecified',
#  'Chlorimuron-ethyl',
#  'Chlorinated solvents, unspecified',
#  'Chlorine',
#  'Chlormequat',
#  'Chlormequat chloride',
#  'Chloroacetic acid',
#  'Chloroacetyl chloride',
#  'Chloroform',
#  'Chloropicrin',
#  'Chlorosilane, trimethyl-',
#  'Chlorosulfonic acid',
#  'Chlorothalonil',
#  'Chlorpyrifos',
#  'Chlorpyrifos methyl',
#  'Chlorsulfuron',
#  'Chlorthal',
#  'Chlozolinate',
#  'Choline chloride',
#  'Chromium',
#  'Chromium IV',
#  'Chromium VI',
#  'Chromium-51',
#  'Chrysene',
#  'Cinidon-ethyl',
#  'Clethodim',
#  'Clodinafop-propargyl',
#  'Clofentezine',
#  'Clomazone',
#  'Clopyralid',
#  'Cloquintocet-mexyl',
#  'Cloransulam-methyl',
#  'Clothianidin',
#  'Cobalt',
#  'Cobalt-57',
#  'Cobalt-58',
#  'Cobalt-60',
#  'Copper',
#  'Cu-HDO',
#  'Cumene',
#  'Curium alpha',
#  'Curium-242',
#  'Curium-244',
#  'Cyanamide',
#  'Cyanazine',
#  'Cyanide',
#  'Cyanoacetic acid',
#  'Cyazofamid',
#  'Cyclanilide',
#  'Cyclohexane',
#  'Cyclopentane',
#  'Cycloxydim',
#  'Cycluron',
#  'Cyhalothrin',
#  'Cyhalothrin, gamma-',
#  'Cyhexatin',
#  'Cymoxanil',
#  'Cypermethrin',
#  'Cyproconazole',
#  'Cyprodinil',
#  'Cyromazine',
#  'DNOC',
#  'DOC, Dissolved Organic Carbon',
#  'Daminozide',
#  'Dazomet',
#  'Decanoic acid',
#  'Deltamethrin',
#  'Desmedipham',
#  'Diafenthiuron',
#  'Dialifor',
#  'Diazinon',
#  'Dibenz(a,h)anthracene',
#  'Dibutyltin',
#  'Dicamba',
#  'Dichlobenil',
#  'Dichlofluanid',
#  'Dichlorodimethylsilane',
#  'Dichlorprop',
#  'Dichlorprop-P',
#  'Dichlorvos',
#  'Dichromate',
#  'Diclofop',
#  'Diclofop-methyl',
#  'Dicofol',
#  'Dicrotophos',
#  'Dienochlor',
#  'Diethanolamine',
#  'Diethyl ether',
#  'Diethylamine',
#  'Diethylene glycol',
#  'Difenoconazole',
#  'Diflubenzuron',
#  'Diflufenican',
#  'Diflufenzopyr-sodium',
#  'Diisobutyl ketone',
#  'Dimefuron',
#  'Dimethachlor',
#  'Dimethenamid',
#  'Dimethenamid-P',
#  'Dimethipin',
#  'Dimethoate',
#  'Dimethomorph',
#  'Dimethyl carbonate',
#  'Dimethyl ether',
#  'Dimethyl hexanediol',
#  'Dimethyl hexynediol',
#  'Dimethyl malonate',
#  'Dimethylamine',
#  'Dimethyldichlorosilane',
#  'Dinitrogen monoxide',
#  'Dinitrogen tetroxide',
#  'Dinocap',
#  'Dinoseb',
#  'Diofenolan',
#  'Diphenylether-compound',
#  'Diphenyltin',
#  'Dipropylamine',
#  'Diquat',
#  'Diquat dibromide',
#  'Disinfectants, unspecified',
#  'Disulfoton',
#  'Diuron',
#  'Dodecanol',
#  'Dodemorph',
#  'Dodine',
#  'Endosulfan',
#  'Endothall',
#  'Energy, geothermal, converted',
#  'Energy, gross calorific value, in biomass',
#  'Energy, gross calorific value, in biomass, primary forest',
#  'Energy, kinetic (in wind), converted',
#  'Energy, potential (in hydropower reservoir), converted',
#  'Energy, solar, converted',
#  'Epichlorohydrin',
#  'Epoxiconazole',
#  'Esfenvalerate',
#  'Ethalfluralin',
#  'Ethane',
#  'Ethane thiol',
#  'Ethane, 1,1,1,2-tetrafluoro-, HFC-134a',
#  'Ethane, 1,1,1-trichloro-, HCFC-140',
#  'Ethane, 1,1,1-trifluoro-, HFC-143a',
#  'Ethane, 1,1,2-trichloro-',
#  'Ethane, 1,1,2-trichloro-1,2,2-trifluoro-, CFC-113',
#  'Ethane, 1,1-dichloro-1-fluoro-, HCFC-141b',
#  'Ethane, 1,1-difluoro-, HFC-152a',
#  'Ethane, 1,2-dichloro-',
#  'Ethane, 1,2-dichloro-1,1,2,2-tetrafluoro-, CFC-114',
#  'Ethane, 1-chloro-1,1-difluoro-, HCFC-142b',
#  'Ethane, 2,2-dichloro-1,1,1-trifluoro-, HCFC-123',
#  'Ethane, 2-chloro-1,1,1,2-tetrafluoro-, HCFC-124',
#  'Ethane, chloropentafluoro-, CFC-115',
#  'Ethane, hexachloro-',
#  'Ethane, hexafluoro-, HFC-116',
#  'Ethane, pentafluoro-, HFC-125',
#  'Ethanol',
#  'Ethene',
#  'Ethene, chloro-',
#  'Ethene, tetrachloro-',
#  'Ethene, trichloro-',
#  'Ethephon',
#  'Ethiofencarb',
#  'Ethofumesate',
#  'Ethoprop',
#  'Ethyl acetate',
#  'Ethyl cellulose',
#  'Ethylamine',
#  'Ethylene diamine',
#  'Ethylene oxide',
#  'Ethyne',
#  'Etoxazole',
#  'Etridiazole',
#  'Famoxadone',
#  'Fenamidone',
#  'Fenamiphos',
#  'Fenazaquin',
#  'Fenbuconazole',
#  'Fenbutatin oxide',
#  'Fenfuram',
#  'Fenitrothion',
#  'Fenoxaprop',
#  'Fenoxaprop ethyl ester',
#  'Fenoxaprop-P ethyl ester',
#  'Fenoxycarb',
#  'Fenpiclonil',
#  'Fenpropathrin',
#  'Fenpropidin',
#  'Fenpropimorph',
#  'Fenpyroximate',
#  'Fentin acetate',
#  'Fentin hydroxide',
#  'Fipronil',
#  'Fish, demersal, in ocean',
#  'Fish, pelagic, in ocean',
#  'Flazasulfuron',
#  'Florasulam',
#  'Fluazifop',
#  'Fluazifop-P-butyl',
#  'Fluazifop-p-butyl',
#  'Fluazinam',
#  'Flucarbazone sodium salt',
#  'Fludioxonil',
#  'Flufenacet',
#  'Flumetsulam',
#  'Flumiclorac-pentyl',
#  'Flumioxazin',
#  'Fluometuron',
#  'Fluoranthene',
#  'Fluorene',
#  'Fluoride',
#  'Fluorine',
#  'Fluorochloridone',
#  'Fluoroglycofen',
#  'Fluoroglycofen-ethyl',
#  'Fluosilicic acid',
#  'Flupyrsulfuron-methyl',
#  'Fluquinconazole',
#  'Flurenol',
#  'Flurochloridone',
#  'Fluroxypyr',
#  'Flurtamone',
#  'Flusilazole',
#  'Flutolanil',
#  'Folpet',
#  'Fomesafen',
#  'Fonofos',
#  'Foramsulfuron',
#  'Formaldehyde',
#  'Formamide',
#  'Formate',
#  'Formic acid',
#  'Fosetyl',
#  'Fosetyl-aluminium',
#  'Fuberidazole',
#  'Fungicides, unspecified',
#  'Furalaxyl',
#  'Furan',
#  'Furathiocarb',
#  'Furfural',
#  'Glucose',
#  'Glufosinate',
#  'Glufosinate ammonium',
#  'Glutaraldehyde',
#  'Glyphosate',
#  'Gold',
#  'Halosulfuron-methyl',
#  'Haloxyfop- (R) Methylester',
#  'Heat, waste',
#  'Helium',
#  'Heptane',
#  'Heptenophos',
#  'Herbicides, unspecified',
#  'Hexaconazole',
#  'Hexaflumuron',
#  'Hexamethyldisilizane',
#  'Hexane',
#  'Hexazinone',
#  'Hexythiazox',
#  'Hydramethylnon',
#  'Hydrazine',
#  'Hydrocarbons, aliphatic, alkanes, cyclic',
#  'Hydrocarbons, aliphatic, alkanes, unspecified',
#  'Hydrocarbons, aliphatic, unsaturated',
#  'Hydrocarbons, aromatic',
#  'Hydrocarbons, chlorinated',
#  'Hydrocarbons, unspecified',
#  'Hydrogen',
#  'Hydrogen carbonate',
#  'Hydrogen chloride',
#  'Hydrogen fluoride',
#  'Hydrogen peroxide',
#  'Hydrogen sulfide',
#  'Hydrogen-3, Tritium',
#  'Hydroxide',
#  'Hymexazol',
#  'Hypochlorite',
#  'Imazalil',
#  'Imazamox',
#  'Imazapyr',
#  'Imazaquin',
#  'Imazethapyr',
#  'Imidacloprid',
#  'Indeno(1,2,3-cd)pyrene',
#  'Indoxacarb',
#  'Insecticides, unspecified',
#  'Iodide',
#  'Iodine',
#  'Iodine-129',
#  'Iodine-131',
#  'Iodine-133',
#  'Iodine-135',
#  'Iodosulfuron',
#  'Iodosulfuron-methyl-sodium',
#  'Ioxynil',
#  'Iprovalicarb',
#  'Iron',
#  'Iron-59',
#  'Isobutane',
#  'Isocyanic acid',
#  'Isoprene',
#  'Isopropylamine',
#  'Isoproturon',
#  'Isoxadifen-ethyl',
#  'Isoxaflutole',
#  'Kaolin',
#  'Kresoxim-methyl',
#  'Krypton-85',
#  'Krypton-85m',
#  'Krypton-87',
#  'Krypton-88',
#  'Krypton-89',
#  'Lactic acid',
#  'Lactofen',
#  'Lambda-cyhalothrin',
#  'Lanthanum',
#  'Lanthanum-140',
#  'Lead',
#  'Lead-210',
#  'Lenacil',
#  'Lindane',
#  'Linuron',
#  'Lithium',
#  'Lithium carbonate',
#  'Lithium, 0.15% in brine, in ground',
#  'Lufenuron',
#  'MCPB',
#  'Magnesium',
#  'Magnesium phosphide',
#  'Malathion',
#  'Maleic anhydride',
#  'Maleic hydrazide',
#  'Mancozeb',
#  'Mandipropamid',
#  'Maneb',
#  'Manganese',
#  'Manganese-54',
#  'Manganese-55',
#  'Mecoprop',
#  'Mecoprop-P',
#  'Mefenpyr',
#  'Mefenpyr-diethyl',
#  'Mepanipyrim',
#  'Mepiquat chloride',
#  'Mepronil',
#  'Mercury',
#  'Mesosulfuron',
#  'Mesosulfuron-methyl (prop)',
#  'Mesotrione',
#  'Metalaxil',
#  'Metalaxyl-M',
#  'Metamitron',
#  'Metazachlor',
#  'Metconazole',
#  'Methabenzthiazuron',
#  'Methamidophos',
#  'Methane',
#  'Methane, bromo-, Halon 1001',
#  'Methane, bromochlorodifluoro-, Halon 1211',
#  'Methane, bromotrifluoro-, Halon 1301',
#  'Methane, chlorodifluoro-, HCFC-22',
#  'Methane, chlorotrifluoro-, CFC-13',
#  'Methane, dichloro-, HCC-30',
#  'Methane, dichlorodifluoro-, CFC-12',
#  'Methane, dichlorofluoro-, HCFC-21',
#  'Methane, difluoro-, HFC-32',
#  'Methane, fossil',
#  'Methane, monochloro-, R-40',
#  'Methane, trichlorofluoro-, CFC-11',
#  'Methane, trifluoro-, HFC-23',
#  'Methanesulfonic acid',
#  'Methanol',
#  'Methidathion',
#  'Methiocarb',
#  'Methomyl',
#  'Methoprene',
#  'Methoxyfenozide',
#  'Methyl acetate',
#  'Methyl acrylate',
#  'Methyl borate',
#  'Methyl ethyl ketone',
#  'Methyl formate',
#  'Methyl lactate',
#  'Methyl pentane',
#  'Methylamine',
#  'Metiram',
#  'Metobromuron',
#  'Metolachlor',
#  'Metosulam',
#  'Metribuzin',
#  'Metsulfuron-methyl',
#  'Mevinfos',
#  'Mineral oil',
#  'Molinate',
#  'Molybdenum',
#  'Molybdenum-99',
#  'Monobutyltin',
#  'Monocrotophos',
#  'Monoethanolamine',
#  'Monolinuron',
#  'Monophenyltin',
#  'Myclobutanil',
#  'N-Bromoacetamide',
#  'Naled',
#  'Naphthalene',
#  'Napropamide',
#  'Neburon',
#  'Neptunium-237',
#  'Nickel',
#  'Nicosulfuron',
#  'Niobium-95',
#  'Nitrate',
#  'Nitric acid',
#  'Nitrite',
#  'Nitrobenzene',
#  'Nitrogen',
#  'Nitrogen dioxide',
#  'Nitrogen fluoride',
#  'Nitrogen oxides',
#  'Nitrogen, organic bound',
#  'Nitrothal-isopropyl',
#  'Noble gases, radioactive, unspecified',
#  'Norflurazon',
#  'Novaluron',
#  'Occupation, annual crop',
#  'Occupation, annual crop, flooded crop',
#  'Occupation, annual crop, greenhouse',
#  'Occupation, annual crop, irrigated',
#  'Occupation, annual crop, irrigated, extensive',
#  'Occupation, annual crop, irrigated, intensive',
#  'Occupation, annual crop, non-irrigated',
#  'Occupation, annual crop, non-irrigated, extensive',
#  'Occupation, annual crop, non-irrigated, intensive',
#  'Occupation, construction site',
#  'Occupation, cropland fallow (non-use)',
#  'Occupation, dump site',
#  'Occupation, forest, extensive',
#  'Occupation, forest, intensive',
#  'Occupation, forest, primary (non-use)',
#  'Occupation, forest, secondary (non-use)',
#  'Occupation, forest, unspecified',
#  'Occupation, grassland, natural (non-use)',
#  'Occupation, grassland, natural, for livestock grazing',
#  'Occupation, heterogeneous, agricultural',
#  'Occupation, industrial area',
#  'Occupation, inland waterbody, unspecified',
#  'Occupation, mineral extraction site',
#  'Occupation, pasture, man made',
#  'Occupation, pasture, man made, extensive',
#  'Occupation, pasture, man made, intensive',
#  'Occupation, permanent crop',
#  'Occupation, permanent crop, irrigated',
#  'Occupation, permanent crop, irrigated, extensive',
#  'Occupation, permanent crop, irrigated, intensive',
#  'Occupation, permanent crop, non-irrigated',
#  'Occupation, permanent crop, non-irrigated, extensive',
#  'Occupation, permanent crop, non-irrigated, intensive',
#  'Occupation, seabed, drilling and mining',
#  'Occupation, seabed, infrastructure',
#  'Occupation, shrub land, sclerophyllous',
#  'Occupation, traffic area, rail network',
#  'Occupation, traffic area, rail/road embankment',
#  'Occupation, traffic area, road network',
#  'Occupation, unspecified',
#  'Occupation, unspecified, natural (non-use)',
#  'Occupation, urban, continuously built',
#  'Occupation, urban, discontinuously built',
#  'Occupation, urban/industrial fallow (non-use)',
#  'Octaethylene glycol monododecyl ether',
#  'Octanoic acid',
#  'Oils, unspecified',
#  'Orbencarb',
#  'Organic carbon',
#  'Oryzalin',
#  'Oxadixyl',
#  'Oxamyl',
#  'Oxasulfuron',
#  'Oxyfluorfen',
#  'Oxygen',
#  'Ozone',
#  'P-tert-amylphenol',
#  'PAH, polycyclic aromatic hydrocarbons',
#  'Palladium',
#  'Paraffins',
#  'Paraquat',
#  'Parathion',
#  'Particulates, < 2.5 um',
#  'Particulates, > 10 um',
#  'Particulates, > 2.5 um, and < 10um',
#  'Penconazole',
#  'Pencycuron',
#  'Pendimethalin',
#  'Pentane',
#  'Perfluoropentane',
#  'Permethrin',
#  'Pesticides, unspecified',
#  'Pethoxamid',
#  'Phenanthrene',
#  'Phenmedipham',
#  'Phenol',
#  'Phenol, pentachloro-',
#  'Phorate',
#  'Phosalone',
#  'Phosgene',
#  'Phosmet',
#  'Phosphate',
#  'Phosphine',
#  'Phosphoric acid',
#  'Phosphorus',
#  'Phosphorus oxychloride',
#  'Phosphorus pentachloride',
#  'Phosphorus trichloride',
#  'Phthalate, butyl-benzyl-',
#  'Phthalate, dibutyl-',
#  'Phthalate, dimethyl-',
#  'Phthalate, dioctyl-',
#  'Picloram',
#  'Picoxystrobin',
#  'Pinoxaden',
#  'Piperonyl butoxide',
#  'Pirimicarb',
#  'Pirimiphos methyl',
#  'Platinum',
#  'Plutonium-238',
#  'Plutonium-241',
#  'Plutonium-alpha',
#  'Polonium-210',
#  'Polychlorinated biphenyls',
#  'Potassium',
#  'Potassium chloride',
#  'Potassium-40',
#  'Primisulfuron',
#  'Prochloraz',
#  'Procymidone',
#  'Profenofos',
#  'Prohexadione-calcium',
#  'Promethium-147',
#  'Prometryn',
#  'Pronamide',
#  'Propachlor',
#  'Propamocarb',
#  'Propamocarb HCl',
#  'Propanal',
#  'Propane',
#  'Propanil',
#  'Propaquizafop',
#  'Propargite',
#  'Propene',
#  'Propham',
#  'Propiconazole',
#  'Propineb',
#  'Propionic acid',
#  'Propoxycarbazone-sodium (prop)',
#  'Propylamine',
#  'Propylene oxide',
#  'Proquinazid',
#  'Prosulfocarb',
#  'Prosulfuron',
#  'Protactinium-234',
#  'Prothioconazol',
#  'Pymetrozine',
#  'Pyraclostrobin (prop)',
#  'Pyraflufen-ethyl',
#  'Pyrazophos',
#  'Pyrene',
#  'Pyrethrin',
#  'Pyrethrum',
#  'Pyridate',
#  'Pyrifenox',
#  'Pyrimethanil',
#  'Pyriproxyfen',
#  'Pyrithiobac sodium salt',
#  'Quinclorac',
#  'Quinmerac',
#  'Quinoxyfen',
#  'Quizalofop ethyl ester',
#  'Quizalofop-P',
#  'Quizalofop-p-ethyl',
#  'Radioactive species, Nuclides, unspecified',
#  'Radioactive species, alpha emitters',
#  'Radioactive species, other beta emitters',
#  'Radium-224',
#  'Radium-226',
#  'Radium-228',
#  'Radon-220',
#  'Radon-222',
#  'Rhodium',
#  'Rimsulfuron',
#  'Rotenone',
#  'Rubidium',
#  'Ruthenium-103',
#  'Ruthenium-106',
#  'Scandium',
#  'Selenium',
#  'Sethoxydim',
#  'Siduron',
#  'Silicon',
#  'Silicon dioxide',
#  'Silicon tetrachloride',
#  'Silicon tetrafluoride',
#  'Silthiofam',
#  'Silver',
#  'Silver-110',
#  'Simazine',
#  'Sodium',
#  'Sodium chlorate',
#  'Sodium dichromate',
#  'Sodium fluorosilicate',
#  'Sodium formate',
#  'Sodium hydroxide',
#  'Sodium hypochlorite',
#  'Sodium-24',
#  'Solids, inorganic',
#  'Spinosad',
#  'Spirodiclofen',
#  'Spiroxamine',
#  'Starane',
#  'Strontium',
#  'Strontium-89',
#  'Strontium-90',
#  'Styrene',
#  'Sulcotrione',
#  'Sulfate',
#  'Sulfentrazone',
#  'Sulfide',
#  'Sulfite',
#  'Sulfosate',
#  'Sulfosulfuron',
#  'Sulfotep',
#  'Sulfur',
#  'Sulfur dioxide',
#  'Sulfur hexafluoride',
#  'Sulfur oxides',
#  'Sulfur trioxide',
#  'Sulfuric acid',
#  'Suspended solids, unspecified',
#  'TOC, Total Organic Carbon',
#  'Tebuconazole',
#  'Tebufenozide',
#  'Tebufenpyrad',
#  'Tebupirimphos',
#  'Tebutam',
#  'Technetium-99',
#  'Technetium-99m',
#  'Teflubenzuron',
#  'Tefluthrin',
#  'Tellurium',
#  'Tellurium-123m',
#  'Tellurium-132',
#  'Tepraloxydim',
#  'Terbacil',
#  'Terbufos',
#  'Terbuthylazin',
#  'Terbutryn',
#  'Terpenes',
#  'Tetramethyl ammonium hydroxide',
#  'Thallium',
#  'Thiabendazole',
#  'Thiacloprid',
#  'Thiamethoxam',
#  'Thidiazuron',
#  'Thifensulfuron',
#  'Thifensulfuron-methyl',
#  'Thiobencarb',
#  'Thiocyanate, ion',
#  'Thiocyclam',
#  'Thiodicarb',
#  'Thiram',
#  'Thorium',
#  'Thorium-228',
#  'Thorium-230',
#  'Thorium-232',
#  'Thorium-234',
#  'Tin',
#  'Titanium',
#  'Toluene',
#  'Tolylfluanid',
#  'Tralkoxydim',
#  'Tralomethrin',
#  'Transformation, from annual crop',
#  'Transformation, from annual crop, greenhouse',
#  'Transformation, from annual crop, irrigated',
#  'Transformation, from annual crop, irrigated, extensive',
#  'Transformation, from annual crop, irrigated, intensive',
#  'Transformation, from annual crop, non-irrigated',
#  'Transformation, from annual crop, non-irrigated, extensive',
#  'Transformation, from annual crop, non-irrigated, intensive',
#  'Transformation, from arable land, unspecified use',
#  'Transformation, from cropland fallow (non-use)',
#  'Transformation, from dump site',
#  'Transformation, from dump site, inert material landfill',
#  'Transformation, from dump site, residual material landfill',
#  'Transformation, from dump site, sanitary landfill',
#  'Transformation, from dump site, slag compartment',
#  'Transformation, from forest, extensive',
#  'Transformation, from forest, intensive',
#  'Transformation, from forest, primary (non-use)',
#  'Transformation, from forest, secondary (non-use)',
#  'Transformation, from forest, unspecified',
#  'Transformation, from grassland, natural (non-use)',
#  'Transformation, from grassland, natural, for livestock grazing',
#  'Transformation, from heterogeneous, agricultural',
#  'Transformation, from industrial area',
#  'Transformation, from inland waterbody, unspecified',
#  'Transformation, from mineral extraction site',
#  'Transformation, from pasture, man made',
#  'Transformation, from pasture, man made, extensive',
#  'Transformation, from pasture, man made, intensive',
#  'Transformation, from permanent crop',
#  'Transformation, from permanent crop, irrigated',
#  'Transformation, from permanent crop, irrigated, extensive',
#  'Transformation, from permanent crop, irrigated, intensive',
#  'Transformation, from permanent crop, non-irrigated',
#  'Transformation, from permanent crop, non-irrigated, extensive',
#  'Transformation, from permanent crop, non-irrigated, intensive',
#  'Transformation, from river, natural (non-use)',
#  'Transformation, from seabed, drilling and mining',
#  'Transformation, from seabed, infrastructure',
#  'Transformation, from seabed, unspecified',
#  'Transformation, from shrub land, sclerophyllous',
#  'Transformation, from traffic area, rail network',
#  'Transformation, from traffic area, rail/road embankment',
#  'Transformation, from traffic area, road network',
#  'Transformation, from unspecified',
#  'Transformation, from unspecified, natural (non-use)',
#  'Transformation, from urban, continuously built',
#  'Transformation, from urban, discontinuously built',
#  'Transformation, from urban/industrial fallow (non-use)',
#  'Transformation, from wetland, inland (non-use)',
#  'Transformation, to annual crop',
#  'Transformation, to annual crop, greenhouse',
#  'Transformation, to annual crop, irrigated',
#  'Transformation, to annual crop, irrigated, extensive',
#  'Transformation, to annual crop, irrigated, intensive',
#  'Transformation, to annual crop, non-irrigated',
#  'Transformation, to annual crop, non-irrigated, extensive',
#  'Transformation, to annual crop, non-irrigated, intensive',
#  'Transformation, to arable land, unspecified use',
#  'Transformation, to bare area (non-use)',
#  'Transformation, to dump site',
#  'Transformation, to dump site, inert material landfill',
#  'Transformation, to dump site, residual material landfill',
#  'Transformation, to dump site, sanitary landfill',
#  'Transformation, to dump site, slag compartment',
#  'Transformation, to forest, extensive',
#  'Transformation, to forest, intensive',
#  'Transformation, to forest, primary (non-use)',
#  'Transformation, to forest, secondary (non-use)',
#  'Transformation, to forest, unspecified',
#  'Transformation, to grassland, natural (non-use)',
#  'Transformation, to grassland, natural, for livestock grazing',
#  'Transformation, to heterogeneous, agricultural',
#  'Transformation, to industrial area',
#  'Transformation, to inland waterbody, unspecified',
#  'Transformation, to mineral extraction site',
#  'Transformation, to pasture, man made',
#  'Transformation, to pasture, man made, extensive',
#  'Transformation, to pasture, man made, intensive',
#  'Transformation, to permanent crop',
#  'Transformation, to permanent crop, irrigated',
#  'Transformation, to permanent crop, irrigated, extensive',
#  'Transformation, to permanent crop, irrigated, intensive',
#  'Transformation, to permanent crop, non-irrigated',
#  'Transformation, to permanent crop, non-irrigated, extensive',
#  'Transformation, to permanent crop, non-irrigated, intensive',
#  'Transformation, to seabed, drilling and mining',
#  'Transformation, to seabed, infrastructure',
#  'Transformation, to seabed, unspecified',
#  'Transformation, to shrub land, sclerophyllous',
#  'Transformation, to traffic area, rail network',
#  'Transformation, to traffic area, rail/road embankment',
#  'Transformation, to traffic area, road network',
#  'Transformation, to unspecified',
#  'Transformation, to unspecified, natural (non-use)',
#  'Transformation, to urban, continuously built',
#  'Transformation, to urban, discontinuously built',
#  'Transformation, to wetland, inland (non-use)',
#  'Triadimenol',
#  'Triasulfuron',
#  'Triazamate',
#  'Tribenuron',
#  'Tribenuron-methyl',
#  'Tribufos',
#  'Tributyltin compounds',
#  'Trichlorfon',
#  'Triclopyr',
#  'Tridemorph',
#  'Triethylene glycol',
#  'Trifloxystrobin',
#  'Triflumizole',
#  'Triflumuron',
#  'Trifluralin',
#  'Triflusulfuron-methyl',
#  'Triforine',
#  'Trimethylamine',
#  'Trinexapac-ethyl',
#  'Trioctyltin',
#  'Triphenyltin',
#  'Trisodium phosphate',
#  'Triticonazole',
#  'Tungsten',
#  'Uranium',
#  'Uranium alpha',
#  'Uranium-234',
#  'Uranium-235',
#  'Uranium-238',
#  'Urea',
#  'VOC, volatile organic compounds, unspecified origin',
#  'Vamidothion',
#  'Vanadium',
#  'Vanadium, ion',
#  'Vinclozolin',
#  'Volume occupied, final repository for low-active radioactive waste',
#  'Volume occupied, final repository for radioactive waste',
#  'Volume occupied, reservoir',
#  'Volume occupied, underground deposit',
#  'Water',
#  'Water, in air',
#  'Water, lake',
#  'Water, river',
#  'Water, salt, ocean',
#  'Water, salt, sole',
#  'Water, turbine use, unspecified natural origin',
#  'Wood, hard, standing',
#  'Wood, primary forest, standing',
#  'Wood, soft, standing',
#  ...]

# %%
len(set(sp['Flowable'])), len(set(ei['Flowable']))
# Out:
# (6109, 1405)

# %%
set(sp['Context'])
# Out:
# {'Airborne emissions',
#  'Emissions to soil',
#  'Non material emissions',
#  'Raw materials',
#  'Waterborne emissions'}

# %%
set(ei['Context'])
# Out:
# {'air/indoor',
#  'air/low population density, long-term',
#  'air/lower stratosphere + upper troposphere',
#  'air/non-urban air or from high stacks',
#  'air/unspecified',
#  'air/urban air close to ground',
#  'natural resource/biotic',
#  'natural resource/fossil well',
#  'natural resource/in air',
#  'natural resource/in ground',
#  'natural resource/in water',
#  'natural resource/land',
#  'soil/agricultural',
#  'soil/forestry',
#  'soil/industrial',
#  'soil/unspecified',
#  'water/fossil well',
#  'water/ground-',
#  'water/ground-, long-term',
#  'water/ocean',
#  'water/surface water',
#  'water/unspecified'}
